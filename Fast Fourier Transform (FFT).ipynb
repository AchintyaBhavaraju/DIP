# %%
import numpy as np
import pandas as pd 
import os

# %%
from skimage.io import imread,imshow
image_1=imread(r"C:\Users\achin\Downloads\AND2.jpg")
imshow(image_1)

# %%
image_1.shape
# Out:
# (1080, 1920, 3)

# %%
image_2=imread(r"C:\Users\achin\Downloads\AND1.jpg")
imshow(image_2)

# %%
from  skimage.transform import resize,rescale
image_2=resize(image_2,
              (475,350,3))
imshow(image_2)

# %%
image_1=np.array(image_1,dtype='float64')
image_2.dtype
# Out:
# dtype('float64')

# %%
import cv2
and_img = cv2.bitwise_and(image_1, image_2)
imshow(and_img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16268/863431023.py in <module>
#       1 import cv2
# ----> 2 and_img = cv2.bitwise_and(image_1, image_2)
#       3 imshow(and_img)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'

# %%
or_image= cv2.bitwise_or(image_1, image_2)
imshow(or_image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16268/1697231796.py in <module>
# ----> 1 or_image= cv2.bitwise_or(image_1, image_2)
#       2 imshow(or_image)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
