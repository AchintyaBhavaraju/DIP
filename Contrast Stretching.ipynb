# %%
import cv2
import numpy as np
xp = [0, 64, 128, 192, 255]
fp = [0, 16, 128, 240, 255]
x = np.arange(256)
import matplotlib.pyplot as plt
img_new = cv2.imread('C:/Users/achin/Downloads/cube.jpg',1)
color = ('b','g','r')
table = np.interp(x, xp, fp).astype('uint8')
img = cv2.LUT(img_new, table)
cv2.imshow("original",img_new)
plt.imshow(img_new)
